# %% [markdown]
# #Processamento de Dados

# %% [markdown]
# ##Importação das Bibliotecas

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
# !pip install keras
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: keras in /usr/local/lib/python3.9/dist-packages (2.12.0)

# %% [markdown]
# ##Abertura do Arquivo

# %%
dataset_all = pd.read_csv('Bloco-DadosPOCv2.csv', encoding = 'utf-8')

# %%
dataset_all.head
# Out:
# <bound method NDFrame.head of      Ano        Mês  Dias do mês  Demanda máxima (kW)  \
# 0   2010    Janeiro           31               3087.4
# 1   2010  Fevereiro           28               3191.0
# 2   2010      Março           31               3916.8
# 3   2010      Abril           30               3732.5
# 4   2010       Maio           31               3237.1
# 5   2010      Junho           30               2603.5
# 6   2010      Julho           31               2499.8
# 7   2010     Agosto           31               3156.5
# 8   2010   Setembro           30               3098.9
# 9   2010    Outubro           31               3018.2
# 10  2010   Novembro           30               2764.8
# 11  2010   Dezembro           31               3467.5
# 12  2011    Janeiro           31               2741.8
# 13  2011  Fevereiro           28               3582.7
# 14  2011      Março           31               3559.7
# 15  2011      Abril           30               3721.0
# 16  2011       Maio           31               3075.8
# 17  2011      Junho           30               2603.5
# 18  2011      Julho           31               2188.8
# 19  2011     Agosto           31               3363.8
# 20  2011   Setembro           30               2672.6
# 21  2011    Outubro           31               3363.8
# 22  2011   Novembro           30               3617.3
# 23  2011   Dezembro           31               3225.6
# 24  2013    Janeiro           31               2753.3
# 25  2013  Fevereiro           28               3145.0
# 26  2013      Março           31               3997.4
# 27  2013      Abril           30               3409.9
# 28  2013       Maio           31               3317.8
# 29  2013      Junho           30               2903.0
# 30  2013      Julho           31               2281.0
# 31  2013     Agosto           31               3317.8
# 32  2013   Setembro           30               3421.4
# 33  2013    Outubro           31               3525.1
# 34  2013   Novembro           30               3944.6
# 35  2013   Dezembro           31               3696.0
# 36  2016    Janeiro           31               3393.0
# 37  2016  Fevereiro           28               3024.0
# 38  2016      Março           31               3581.8
# 39  2016      Abril           30               4247.0
# 40  2016       Maio           31               3924.5
# 41  2016      Junho           30               3521.3
# 42  2016      Julho           31               2432.6
# 43  2016     Agosto           31               2567.0
# 44  2016   Setembro           30               2909.8
# 45  2016    Outubro           31               3790.1
# 46  2016   Novembro           30               3689.3
# 47  2016   Dezembro           31               3675.8
#
#     Demanda Contratada (kW)  Consumo Ponta (kWh)  Consumo Fora de Ponta (kWh)  \
# 0                    3800.0            61433.300                   874408.300
# 1                    3800.0            63043.200                   832833.025
# 2                    3800.0            97689.650                  1145070.825
# 3                    3800.0            84809.875                   784432.125
# 4                    3800.0            74067.725                   908939.525
# 5                    3800.0            41276.050                   720235.675
# 6                    3800.0            29482.575                   725713.500
# 7                    3800.0            47900.075                   819731.800
# 8                    3800.0            62565.250                   835885.400
# 9                    3800.0            61263.375                   830062.025
# 10                   3800.0             8593.850                    57412.900
# 11                   3800.0           101203.050                   872838.625
# 12                   3800.0            94446.600                   816289.875
# 13                   3800.0           101139.625                   942560.275
# 14                   3800.0           131702.325                   980245.100
# 15                   3800.0           131368.275                   989672.000
# 16                   3800.0           110574.525                   901454.500
# 17                   3800.0           102553.800                   765679.850
# 18                   3800.0            86218.600                   673743.725
# 19                   3800.0           116285.650                   861699.000
# 41                                    369.86
# 42                                    369.86
# 43                                    369.86
# 44                                    369.86
# 45                                    369.86
# 46                                    369.86
# 47                                    369.86
#
#     Tarifa de Demanda Ponta e Fora de Ponta (R$/kW)  ...  \
# 0                                             12.35  ...
# 1                                             12.35  ...
# 2                                             12.35  ...
# 3                                             12.35  ...
# 4                                             12.35  ...
# 5                                             12.35  ...
# 6                                             12.35  ...
# 7                                             12.35  ...
# 8                                             12.35  ...
# 9                                             12.35  ...
# 10                                            12.35  ...
# 11                                            12.35  ...
# 12                                            12.35  ...
# 13                                            12.35  ...
# 14                                            12.35  ...
# 15                                            12.35  ...
# 16                                            12.35  ...
# 17                                            12.35  ...
# 18                                            12.35  ...
# 19                                            12.35  ...
# 20                                            12.35  ...
# 21                                            12.35  ...
# 22                                            12.35  ...
# 23                                            12.35  ...
# 24                                            12.35  ...
# 25                                            12.35  ...
# 26                                            12.35  ...
# 27                                            12.35  ...
# 28                                            12.35  ...
# 29                                            12.35  ...
# 30                                            12.35  ...
# 31                                            12.35  ...
# 32                                            12.35  ...
# 33                                            12.35  ...
# 34                                            12.35  ...
# 35                                            12.35  ...
# 36                                            12.35  ...
# 37                                            12.35  ...
# 38                                            12.35  ...
# 39                                            12.35  ...
# 40                                            12.35  ...
# 41                                            12.35  ...
# 42                                            12.35  ...
# 43                                            12.35  ...
# 44                                            12.35  ...
# 45                                            12.35  ...
# 46                                            12.35  ...
# 47                                            12.35  ...
#
#     Preço Contratado no ACL (R$/MWh)  PLDmed  Perdas na Rede Básica (%)  \
# 0                             202.41   12.91                          3
# 1                             202.41   13.82                          3
# 2                             202.41   27.24                          3
# 3                             202.41   21.47                          3
# 4                             202.41   32.34                          3
# 5                             202.41   67.70                          3
# 6                             202.41   89.61                          3
# 7                             202.41  116.66                          3
# 8                             202.41  132.10                          3
# 9                             202.41  137.78                          3
# 10                            202.41  116.68                          3
# 11                            202.41   71.62                          3
# 12                            202.41   28.19                          3
# 13                            202.41   49.59                          3
# 14                            202.41   23.41                          3
# 15                            202.41   12.20                          3
# 16                            202.41   17.35                          3
# 17                            202.41   31.80                          3
# 18                            202.41   23.08                          3
# 19                            202.41   19.61                          3
# 20                            202.41   21.18                          3
# 21                            202.41   37.14                          3
# 22                            202.41   45.55                          3
# 23                            202.41   44.47                          3
# 24                            202.41  413.95                          3
# 25                            202.41  214.54                          3
# 26                            202.41  339.75                          3
# 27                            202.41  196.13                          3
# 28                            202.41  344.84                          3
# 29                            202.41  207.62                          3
# 30                            202.41  121.29                          3
# 31                            202.41  163.38                          3
# 32                            202.41  266.16                          3
# 33                            202.41  260.99                          3
# 34                            202.41  331.07                          3
# 35                            202.41  290.72                          3
# 36                            202.41   35.66                          3
# 37                            202.41   30.42                          3
# 38                            202.41   37.73                          3
# 39                            202.41   49.42                          3
# 40                            202.41   75.93                          3
# 41                            202.41   61.32                          3
# 42                            202.41   83.43                          3
# 43                            202.41  115.58                          3
# 44                            202.41  149.02                          3
# 45                            202.41  200.21                          3
# 46                            202.41  166.05                          3
# 47                            202.41  122.19                          3
#
# 18                                 0.6                                 1.3
# 19                                 0.6                                 1.3
# 20                                 0.6                                 1.3
# 21                                 0.6                                 1.3
# 22                                 0.6                                 1.3
# 23                                 0.6                                 1.3
# 24                                 0.6                                 1.3
# 25                                 0.6                                 1.3
# 26                                 0.6                                 1.3
# 27                                 0.6                                 1.3
# 28                                 0.6                                 1.3
# 29                                 0.6                                 1.3
# 30                                 0.6                                 1.3
# 31                                 0.6                                 1.3
# 32                                 0.6                                 1.3
# 33                                 0.6                                 1.3
# 34                                 0.6                                 1.3
# 35                                 0.6                                 1.3
# 36                                 0.6                                 1.3
# 37                                 0.6                                 1.3
# 38                                 0.6                                 1.3
# 39                                 0.6                                 1.3
# 40                                 0.6                                 1.3
# 41                                 0.6                                 1.3
# 42                                 0.6                                 1.3
# 43                                 0.6                                 1.3
# 44                                 0.6                                 1.3
# 45                                 0.6                                 1.3
# 46                                 0.6                                 1.3
# 47                                 0.6                                 1.3
#
# [48 rows x 26 columns]>

# %% [markdown]
# ##Dados de Consumo e Demanda a Serem Utilizados

# %%
dataset_consume_demand = dataset_all.iloc[:,3:7]

# %%
dataset_consume_demand.head()
# Out:
#    Demanda máxima (kW)  Demanda Contratada (kW)  Consumo Ponta (kWh)  \
# 0               3087.4                   3800.0            61433.300
# 1               3191.0                   3800.0            63043.200
# 2               3916.8                   3800.0            97689.650
# 3               3732.5                   3800.0            84809.875
# 4               3237.1                   3800.0            74067.725
#
#    Consumo Fora de Ponta (kWh)
# 0                   874408.300
# 1                   832833.025
# 2                  1145070.825
# 3                   784432.125
# 4                   908939.525

# %%
len(dataset_consume_demand)
# Out:
# 48

# %% [markdown]
# ##Dados de Treinamento - Consumo Ponta

# %%
highprice_consume_training_set = dataset_consume_demand.iloc[:42,2:3].values

# %%
highprice_consume_training_set
# Out:
# array([[ 61433.3  ],
#        [ 63043.2  ],
#        [ 97689.65 ],
#        [ 84809.875],
#        [ 74067.725],
#        [ 41276.05 ],
#        [ 29482.575],
#        [ 47900.075],
#        [ 62565.25 ],
#        [ 61263.375],
#        [  8593.85 ],
#        [101203.05 ],
#        [ 94446.6  ],
#        [101139.625],
#        [131702.325],
#        [131368.275],
#        [110574.525],
#        [102553.8  ],
#        [ 86218.6  ],
#        [116285.65 ],
#        [114013.725],
#        [117193.   ],
#        [116550.75 ],
#        [ 91621.175],
#        [ 49078.1  ],
#        [ 62600.   ],
#        [ 95227.25 ],
#        [ 78413.65 ],
#        [ 75548.075],
#        [ 44936.875],
#        [ 14394.05 ],
#        [ 63129.65 ],
#        [ 78664.325],
#        [ 71539.4  ],
#        [ 58680.475],
#        [ 65410.725],
#        [ 82898.   ],
#        [ 82095.   ],
#        [105844.   ],
#        [157722.   ],
#        [131371.   ],
#        [121908.   ]])

# %% [markdown]
# ##Gráfico da Série Temporal - Consumo Ponta

# %%
plt.plot(highprice_consume_training_set)
plt.xlabel("Meses")
plt.ylabel("Kilowatts")
plt.title("Consumo Ponta")
plt.show()

# %% [markdown]
# ##Normalização - Consumo Ponta

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0, 1))
highprice_consume_training_set_scaled = sc.fit_transform(highprice_consume_training_set)

# %% [markdown]
# ##Criação da Estrutura de Dados - Consumo Ponta

# %%
window = 10
trainSize = len(highprice_consume_training_set_scaled)
horizon = 10
highprice_consume_X_train = []
highprice_consume_y_train = []
for i in range(window, trainSize-horizon):
    highprice_consume_X_train.append(highprice_consume_training_set_scaled[i-window:i, 0])
    highprice_consume_y_train.append(highprice_consume_training_set_scaled[i:i+window, 0])
highprice_consume_X_train, highprice_consume_y_train = np.array(highprice_consume_X_train), np.array(highprice_consume_y_train)

# %% [markdown]
# ##Reshaping - Consumo Ponta

# %%
highprice_consume_X_train.shape
# Out:
# (22, 10)

# %%
highprice_consume_y_train.shape
# Out:
# (22, 10)

# %%
highprice_consume_X_train = np.reshape(highprice_consume_X_train, (highprice_consume_X_train.shape[0], highprice_consume_X_train.shape[1], 1))

# %%
highprice_consume_X_train.shape
# Out:
# (22, 10, 1)

# %%
highprice_consume_y_train = np.reshape(highprice_consume_y_train, (highprice_consume_y_train.shape[0], highprice_consume_y_train.shape[1], 1))

# %%
highprice_consume_y_train.shape
# Out:
# (22, 10, 1)

# %% [markdown]
# #Construção da RNN - Consumo Ponta

# %% [markdown]
# ##Importação das Bibliotecas

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %% [markdown]
# ##Construção da Rede Completa

# %%
# Inicializar a RNN
regressor = Sequential()

# Adicionar a primeira camada LSTM e Dropout 
regressor.add(LSTM(units = 100, return_sequences = True, input_shape = (highprice_consume_X_train.shape[1], 1)))
#regressor.add(Dropout(0.2))
 
# Adicionar a segunda camada LSTM e Dropout
#regressor.add(LSTM(units = 80, return_sequences = True))
#regressor.add(Dropout(0.2))
 
# Adicionar a terceira camada LSTM e Dropout
regressor.add(LSTM(units = 20))
regressor.add(Dropout(0.3))
 
# camada de saída
regressor.add(Dense(units = 1))
 
# Compilar a rede
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Visualizar a rede
regressor.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_8 (LSTM)               (None, 10, 100)           40800
#
#  lstm_9 (LSTM)               (None, 20)                9680
#
#  dropout_4 (Dropout)         (None, 20)                0
#
#  dense_4 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 50,501
# Trainable params: 50,501
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##Treinamento

# %%
regressor.fit(highprice_consume_X_train, highprice_consume_y_train, epochs = 200, batch_size = 7)
# Out:
# Epoch 1/200
# 4/4 [==============================] - 5s 14ms/step - loss: 0.2437
# Epoch 2/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1135
# Epoch 3/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0827
# Epoch 4/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0924
# Epoch 5/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0788
# Epoch 6/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0694
# Epoch 7/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0702
# Epoch 8/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0718
# Epoch 9/200
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0712
# Epoch 10/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0703
# Epoch 11/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0538
# Epoch 12/200
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0652
# Epoch 13/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0612
# Epoch 14/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0684
# Epoch 15/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0562
# Epoch 16/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0643
# Epoch 17/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0619
# Epoch 18/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0562
# Epoch 19/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0488
# Epoch 20/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0659
# Epoch 21/200
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0566
# Epoch 22/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0407
# Epoch 23/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0503
# Epoch 24/200
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0434
# Epoch 25/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0469
# Epoch 26/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0453
# Epoch 27/200
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0594
# Epoch 28/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0518
# Epoch 29/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0421
# Epoch 30/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0555
# Epoch 31/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0518
# Epoch 32/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0400
# Epoch 33/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0377
# Epoch 34/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0353
# Epoch 35/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0410
# Epoch 36/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0331
# Epoch 37/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0370
# Epoch 38/200
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0372
# Epoch 39/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0340
# Epoch 40/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0371
# Epoch 41/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0327
# Epoch 42/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0311
# Epoch 43/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.
200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0316
# Epoch 174/200
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0335
# Epoch 175/200
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0365
# Epoch 176/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0302
# Epoch 177/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0389
# Epoch 178/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0333
# Epoch 179/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0317
# Epoch 180/200
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0300
# Epoch 181/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0312
# Epoch 182/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0299
# Epoch 183/200
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0291
# Epoch 184/200
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0320
# Epoch 185/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0302
# Epoch 186/200
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0312
# Epoch 187/200
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0281
# Epoch 188/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0327
# Epoch 189/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0306
# Epoch 190/200
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0320
# Epoch 191/200
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0282
# Epoch 192/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0292
# Epoch 193/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0302
# Epoch 194/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0306
# Epoch 195/200
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0293
# Epoch 196/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0295
# Epoch 197/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0322
# Epoch 198/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0303
# Epoch 199/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0295
# Epoch 200/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0310

# %% [markdown]
# #Previsão e Análise dos Resultados - Consumo Ponta

# %% [markdown]
# ##Dados de Teste

# %%
highprice_consume_test_set = dataset_all.iloc[42:,2:3].values

# %% [markdown]
# ##Construção da Estrutura para Teste

# %%
highprice_consume_total = pd.concat((dataset_consume_demand.iloc[:42,2:3], dataset_consume_demand.iloc[42:,2:3]), axis = 0)
dcd_testLength = len(dataset_consume_demand.iloc[42:,:])
inputs = highprice_consume_total[len(highprice_consume_total) - dcd_testLength - window:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
highprice_consume_X_test = []
for i in range(window, dcd_testLength + window): 
    highprice_consume_X_test.append(inputs[i-window:i, 0])
highprice_consume_X_test = np.array(highprice_consume_X_test)
highprice_consume_X_test = np.reshape(highprice_consume_X_test, (highprice_consume_X_test.shape[0], highprice_consume_X_test.shape[1], 1))

# %% [markdown]
# ##Realização das previsões

# %%
predicted_highprice_consume = regressor.predict(highprice_consume_X_test)
predicted_highprice_consume = sc.inverse_transform(predicted_highprice_consume)
# Out:
# 1/1 [==============================] - 1s 871ms/step

# %%
df_highprice_consume_training_set = pd.DataFrame(highprice_consume_training_set)

# %% [markdown]
# ##Visualização dos Resultados de Treino e Teste

# %%
allTarget_highprice_consume = np.vstack((dataset_consume_demand.iloc[:42,2:3], dataset_consume_demand.iloc[42:,2:3]))
training_predicted_highprice_consume = regressor.predict(highprice_consume_X_train)
training_predicted_highprice_consume = sc.inverse_transform(training_predicted_highprice_consume)
allForecasted_highprice_consume = np.vstack((df_highprice_consume_training_set[0:window], training_predicted_highprice_consume, predicted_highprice_consume))
plt.plot(allTarget_highprice_consume, color = 'red', label = 'Real')
plt.plot(allForecasted_highprice_consume, color = 'blue', label = 'Previsto')
plt.title('Previsão de série temporal')
plt.xlabel('Tempo')
plt.ylabel('Consumo Ponta (kWh)')
plt.legend()
plt.savefig('predictions_training_test.svg')
plt.show()
# Out:
# 1/1 [==============================] - 0s 25ms/step

# %% [markdown]
# #Métricas de Avaliação - Consumo Ponta

# %%
import math
from sklearn.metrics import mean_squared_error
rmse = math.sqrt(mean_squared_error(highprice_consume_test_set, predicted_highprice_consume))
print('RMSE: ', rmse)
# Out:
# RMSE:  64408.77113052292

# %%
mse = mean_squared_error(highprice_consume_test_set, predicted_highprice_consume)
print('MSE: ',mse)
# Out:
# MSE:  4148489798.5440826

# %%
mape = np.mean(np.abs((highprice_consume_test_set - predicted_highprice_consume) / highprice_consume_test_set)) * 100
print('MAPE: ',mape)
# Out:
# MAPE:  207548.78927251344
