# %%
import requests
import json
import pandas as pd

# %%
df_temp = pd.DataFrame(columns=['Local', 'Data', 'Temperatura', 'Umidade', 'Ceu'])
df_temp.to_csv('out.csv', index=False, encoding="utf8")

# %%
df = pd.DataFrame(columns=['name', 'date', 'temperature', 'humidity', 'condition']) #.read_csv('out.csv')
len_df = len(df)
print(len_df)
df.head()
# Out:
# 0
# Empty DataFrame
# Columns: [name, date, temperature, humidity, condition]
# Index: []

# %%
TOkEN = "462f5692d9bb972f685c3ba4fb24da42"

# %%
city = "Rio de Janeiro"
state = "RJ"

# %%
city_url = "http://apiadvisor.climatempo.com.br/api/v1/locale/city?name=" + str(city) + "&state=" + str(state) + "&country=BR&token=" + str(TOkEN)
print("city_url: ", city_url)
print("\n")
response = requests.request("GET", city_url)
return_request  = json.loads(response.text)
print(return_request)
print("\n")
# Out:
# city_url:  http://apiadvisor.climatempo.com.br/api/v1/locale/city?name=Rio de Janeiro&state=RJ&country=BR&token=462f5692d9bb972f685c3ba4fb24da42
#
#
# [{'id': 5959, 'name': 'Rio de Janeiro', 'state': 'RJ', 'country': 'BR  '}, {'id': 73779, 'name': 'Rio de Janeiro - centro', 'state': 'RJ', 'country': 'BR  '}]

# %%
for key in return_request:
    city_id = key['id']

    try:

      register_url = "http://apiadvisor.climatempo.com.br/api-manager/user-token/" + str(TOkEN) + "/locales"
      payload = "localeId[]=" + str(city_id)
      headers = {'Content-Type': 'application/x-www-form-urlencoded'}
      response = requests.request("PUT", register_url, headers=headers, data=payload)

      print(response.text)

      weather_url = "http://apiadvisor.climatempo.com.br/api/v1/weather/locale/" + str(city_id) + "/current?token=" + str(TOkEN)
      weather = requests.request("GET", weather_url)
      return_weather = json.loads(weather.text)
      print(return_weather)

      len_df = len(df)
      df.loc[len_df] = [str(return_weather["name"])] + [str(return_weather['data']["date"])] + [str(return_weather['data']["temperature"])+"ºC"] + [str(return_weather['data']["humidity"])+"%"] + [str(return_weather['data']["condition"])]
      print(df.head())
    except:
      continue
# Out:
# {"status":"success","locales":[5959]}
# {'id': 5959, 'name': 'Rio de Janeiro', 'state': 'RJ', 'country': 'BR  ', 'data': {'temperature': 22, 'wind_direction': 'NE', 'wind_velocity': 6, 'humidity': 94, 'condition': 'Alguma nebulosidade', 'pressure': 1009, 'icon': '2n', 'sensation': 22, 'date': '2022-04-23 00:26:55'}}
#              name                 date temperature humidity  \
# 0  Rio de Janeiro  2022-04-23 00:26:55        22ºC      94%
#
#              condition
# 0  Alguma nebulosidade
# {"error":true,"detail":"Your free plan only allows to update cities after 24 hours from the last update (2022-04-23 00:26:55 America/Sao_Paulo -03:00)"}
# {'error': True, 'detail': 'Access forbidden, you have no acces for this locale: 73779'}

# %%
df.head()
# Out:
#              name                 date temperature humidity  \
# 0  Rio de Janeiro  2022-04-23 00:26:55        22ºC      94%
#
#              condition
# 0  Alguma nebulosidade

# %%
df.to_csv('out.csv', index=False, encoding="utf8")

# %%
city = "Rio de Janeiro"
state = "RJ"

# %%
city_url = "http://apiadvisor.climatempo.com.br/api/v1/locale/city?name=" + str(city) + "&state=" + str(state) + "&country=BR&token=" + str(TOkEN)
print("city_url: ", city_url)
print("\n")
response = requests.request("GET", city_url)
return_request  = json.loads(response.text)
print(return_request)
print("\n")
# Out:
# city_url:  http://apiadvisor.climatempo.com.br/api/v1/locale/city?name=Rio de Janeiro&state=RJ&country=BR&token=462f5692d9bb972f685c3ba4fb24da42
#
#
# [{'id': 5959, 'name': 'Rio de Janeiro', 'state': 'RJ', 'country': 'BR  '}, {'id': 73779, 'name': 'Rio de Janeiro - centro', 'state': 'RJ', 'country': 'BR  '}]

# %%
df_new = pd.DataFrame(columns=['local', 'data', 'prob_chuva', 'precipitacao_chuva', 'temp_min', 'temp_max', 'text_pt', 'resumo', 'madrugada', 'manha', 'tarde', 'noite'])
len_df_new = 0

for key in return_request:
  try:
    city_id = key['id']

    register_url = "http://apiadvisor.climatempo.com.br/api-manager/user-token/" + str(TOkEN) + "/locales"
    payload = "localeId[]=" + str(city_id)
    headers = {'Content-Type': 'application/x-www-form-urlencoded'}
    response = requests.request("PUT", register_url, headers=headers, data=payload)

    print(response.text)

    
    weather_forecast_url = "http://apiadvisor.climatempo.com.br/api/v1/forecast/locale/" + str(city_id) + "/days/15?token=" + str(TOkEN)
    weather_forecast = requests.request("GET", weather_forecast_url)
    return_weather_forecast = json.loads(weather_forecast.text)
    print("-----")
    print(return_weather_forecast)
    print("-----")

    name_state = return_weather_forecast['name']

    for data_weather_forecast in return_weather_forecast['data']:
      date_br = str(data_weather_forecast['date_br'])
      rain_probability = data_weather_forecast['rain']['probability']
      rain_precipitation = data_weather_forecast['rain']['precipitation']
      temperature_min = data_weather_forecast['temperature']['min']
      temperature_max = data_weather_forecast['temperature']['max']

      text_pt = data_weather_forecast['text_icon']['text']['pt']
      phrase_reduced = data_weather_forecast['text_icon']['text']['phrase']['reduced']
      phrase_dawn = data_weather_forecast['text_icon']['text']['phrase']['dawn']
      phrase_morning = data_weather_forecast['text_icon']['text']['phrase']['morning']
      phrase_afternoon = data_weather_forecast['text_icon']['text']['phrase']['afternoon']
      phrase_night = data_weather_forecast['text_icon']['text']['phrase']['night']
      
      
      len_df_new = len(df_new)
      df_new.loc[len_df_new] = [name_state]+[str(date_br)] + [rain_probability]+[rain_precipitation]+[temperature_min]+[temperature_max]+[text_pt]+[phrase_reduced]+[phrase_dawn]+[phrase_morning]+[phrase_afternoon]+[phrase_night]
  except:
    continue
# Out:
# {"error":true,"detail":"Your free plan only allows to update cities after 24 hours from the last update (2022-04-23 00:26:55 America/Sao_Paulo -03:00)"}
# -----
# {'id': 5959, 'name': 'Rio de Janeiro', 'state': 'RJ', 'country': 'BR  ', 'meteogram': 'http://apiadvisor.climatempo.com.br/api/v1/meteogram/locale/5959?token=462f5692d9bb972f685c3ba4fb24da42&hash=d980491f130a88cc67932012171e40c7', 'data': [{'date': '2022-04-23', 'date_br': '23/04/2022', 'humidity': {'min': 32, 'max': 65, 'dawn': {'min': 55, 'max': 62}, 'morning': {'min': 42, 'max': 56}, 'afternoon': {'min': 32, 'max': 46}, 'night': {'min': 49, 'max': 61}}, 'pressure': {'p
, lluvia y tormentas', 'phrase': {'reduced': 'Sol e aumento de nuvens de manhã. Pancadas de chuva à tarde e à noite.', 'morning': 'Sol com algumas nuvens', 'afternoon': 'Sol, pancadas de chuva e trovoadas.', 'night': 'Muitas nuvens, chuva e raios', 'dawn': 'Algumas nuvens'}}}, 'temperature': {'min': 21, 'max': 31, 'dawn': {'min': 24, 'max': 31}, 'morning': {'min': 22, 'max': 24}, 'afternoon': {'min': 28, 'max': 31}, 'night': {'min': 21, 'max': 29}}, 'cloud_coverage': {'low': 0, 'mid': 0, 'high': 0, 'dawn': {'low': 0, 'mid': 0, 'high': 0}, 'morning': {'low': 0, 'mid': 0, 'high': 0}, 'afternoon': {'low': 0, 'mid': 0, 'high': 0}, 'night': {'low': 0, 'mid': 0, 'high': 0}}, 'sun': {'sunrise': '06:09:00', 'sunset': '17:32:00'}}, {'date': '2022-04-25', 'date_br': '25/04/2022', 'humidity': {'min':  ...
# -----
# {"error":true,"detail":"Your free plan only allows to update cities after 24 hours from the last update (2022-04-23 00:26:55 America/Sao_Paulo -03:00)"}
# -----
# {'error': True, 'detail': 'Access forbidden, you have no acces for this locale: 73779'}
# -----

# %%
df_new.head(20)
# Out:
#             local        data prob_chuva precipitacao_chuva temp_min temp_max  \
# 0  Rio de Janeiro  23/04/2022          0                  0       20       35
# 1  Rio de Janeiro  24/04/2022         90                  8       21       31
# 2  Rio de Janeiro  25/04/2022         83                  5       20       31
# 3  Rio de Janeiro  26/04/2022          0                  0       19       32
# 4  Rio de Janeiro  27/04/2022          0                  0       18       33
# 5  Rio de Janeiro  28/04/2022          0                  0       24       30
# 6  Rio de Janeiro  29/04/2022          0                  0       24       29
#
#                                text_pt  \
# 0               Sol com algumas nuvens
# 1  Sol, pancadas de chuva e trovoadas.
# 2                          Sol e Chuva
# 3               Sol com algumas nuvens
# 4               Sol com algumas nuvens
# 5               Sol com algumas nuvens
# 6               Sol com algumas nuvens
#
#                                               resumo               madrugada  \
# 0                 Sol com algumas nuvens. Não chove.          Algumas nuvens
# 1  Sol e aumento de nuvens de manhã. Pancadas de ...          Algumas nuvens
# 2  Sol, com chuva de manhã e diminuição de nuvens...  Algumas nuvens e chuva
# 3                 Sol com algumas nuvens. Não chove.          Algumas nuvens
# 4                 Sol com algumas nuvens. Não chove.          Algumas nuvens
# 5                 Sol com algumas nuvens. Não chove.          Algumas nuvens
# 6                 Sol com algumas nuvens. Não chove.          Algumas nuvens
#
#                     manha                                tarde  \
# 0  Sol com algumas nuvens               Sol com algumas nuvens
# 1  Sol com algumas nuvens  Sol, pancadas de chuva e trovoadas.
# 2             Sol e Chuva               Sol com algumas nuvens
# 3  Sol com algumas nuvens               Sol com algumas nuvens
# 4  Sol com algumas nuvens               Sol com algumas nuvens
# 5  Sol com algumas nuvens               Sol com algumas nuvens
# 6  Sol com algumas nuvens               Sol com algumas nuvens
#
#                           noite
# 0                Algumas nuvens
# 1  Muitas nuvens, chuva e raios
# 2                Algumas nuvens
# 3                Algumas nuvens
# 4                Algumas nuvens
# 5                Algumas nuvens
# 6                Algumas nuvens
